# %% [markdown]
# # PW1 : Adopt Python
# ## Beginning
# ### [Jupyter](http://jupyter-notebook.readthedocs.io/en/latest/index.html)
# The Jupyter Notebook is an interactive computing environment that enables users to author notebook documents that include: - Live code - Interactive widgets - Plots - Narrative text - Equations - Images - Video
# ### [Pandas](http://pandas.pydata.org/pandas-docs/stable/)
# *pandas* is an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.
# ### [Matplotlib](https://matplotlib.org/contents.html)
# Matplotlib is a Python 2D plotting library which produces publication quality figures in a variety of hardcopy formats and interactive environments across platforms. Matplotlib can be used in Python scripts, the Python and IPython shell, the jupyter notebook, web application servers, and four graphical user interface toolkits.
#
# ## Quests
# - Load the CSV 'ashoka' and manipulate data with Pandas (hint : DataFrame)
# - Do some visualisations with your newly created DataFrame

# %% [markdown]
# ## 1. Import librairies
# We are going to use "pandas" for import data and manipulate it.
# And then for the visualisation, we will use matplotlib.
#
# You have to understand It exists thousand of librairies for visualation.
# Here, pandas works very well with matplotlib.

# %%
# Allow matplotlib to show visualation in Jupyter
# %matplotlib inline
#import pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Loading CSV's data
#
# Our data is in a CSV file (like excel).
# Luckly the librairy Pandas has a special function to read a CSV.
# Once your data is read, you can structure them with Pandas using data strucuture !
# * [Link on csv reader](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html)
# * [Link on DataFrame](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html)
#
# ### Load data
#
#  1. Read CSV data
#  2. Create a Pandas DataFrame with those data
#  3. Display the data
#
# #### Do it yourself

# %%
# Read CSV file named "ashoka.csv". Put its content in a variable
data = pd.read_csv('ashoka2.csv')
# Use DataFrame method to create the data structure. Put it in a variable.
df = pd.DataFrame(data)
# Display the DataFrame variable
print(df)
# Out:
#                    time            Firstname      Lastname  \
# 0   28/06/2017 09:49:58            Alexandre    chevallier
# 1   28/06/2017 09:51:54              quentin           qag
# 2   28/06/2017 09:53:34             Baptiste          Roux
# 3   28/06/2017 09:54:27               Elodie          Peto
# 4   28/06/2017 09:55:31            Genevieve          Mich
# 5   03/07/2017 10:29:34            Alexandre        MAIROT
# 6   03/07/2017 10:29:35                    J           Dog
# 7   03/07/2017 10:30:01           Maniouchka          Lala
# 8   03/07/2017 10:30:56                Kelly         Green
# 9   03/07/2017 10:31:10        Juan-Baptista    Pourtalali
# 10  03/07/2017 10:32:39               Romain        Mougin
# 11  03/07/2017 10:37:54                Alina        Danciu
# 12  03/07/2017 10:39:38                Simon         Simon
# 13  03/07/2017 10:48:03               Korben        Dallas
# 14  03/07/2017 10:49:15         Jean Michel        Sancowl
# 15  03/07/2017 10:51:35  je veux pas le dire          anne
# 16  03/07/2017 10:52:10               Marine        Le Pen
# 17  03/07/2017 11:05:10                Marie         Marie
# 18  03/07/2017 11:21:05                Sarah       Cadorel
# 19  03/07/2017 11:31:40                Miaou         Miaou
# 20  03/07/2017 11:34:33            charlotte  montcharmont
#
#                    gender                color  height        area_birth  \
# 0                    Male                  red     182               Goa
# 1                    Male                white     190      Chhattisgarh
# 2                    Male               purple     178       Maharashtra
# 3                  Female                 blue     170             Assam
# 4                  Female                green     172               Goa
# 5                    Male                 blue     178           Other ?
# 6                     Cat                  red     150        Tamil Nadu
# 7                  Female                green     168           Other ?
# 8            undetermined      black and white     175  Himachal Pradesh
# 9                   Trans               indigo     218           Tripura
# 10                   Male                 blue     182           Other ?
# 11                 Female                green     170           Tripura
# 12                   Male               purple     185            Punjab
# 13  Une mite en pull-over  rainbow, of course!     163               Goa
# 14                 Brebis             lipstick     168            Sikkim
# 15                 Female                 bleu     150             Bihar
# 16                 Female          blue marine     170           Other ?
# 17                 Female                jaune     163        Tamil Nadu
# 18                 Female               yellow     157       West Bengal
# 19              i'm a cat                 pink     150        Tamil Nadu
# 20                 Female               rouge      159           Other ?
#
#                 feeling  sleep
# 0        3. comfortable    7.0
# 1        3. comfortable    8.5
# 2         2. no feeling   12.0
# 3        3. comfortable    8.0
# 4        3. comfortable    7.0
# 5         2. no feeling    5.0
# 6   4. very comfortable   24.0
# 7         2. no feeling    6.0
# 8   4. very comfortable   24.0
# 9   4. very comfortable   24.0
# 10        2. no feeling    6.0
# 11       3. comfortable    7.5
# 12          1. not well    6.5
# 13       3. comfortable    9.0
# 14  4. very comfortable   10.5
# 15  4. very comfortable   24.0
# 16          1. not well    4.0
# 17       3. comfortable    7.0
# 18        2. no feeling    8.0
# 19       3. comfortable   24.0
# 20       3. comfortable    7.5

# %% [markdown]
# ## 3. Visualize data
#
# Once your data are loading and structured, **we can start the visualisation**.
# You can check this documentation for graphics with pandas ([HERE](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html))
#
# ### Gender
# First, we'll visualize the number of person by gender:
#  1. Count the number of people by gender
#  2. Display a pie chart
#  3. Show the percentage in the pie
#  4. Do the same with one line of code
#
# #### Do it yourself

# %%
# Use value_counts() method to count people by gender. Put result in variable.
vc = df.gender.value_counts()
# Display a pie chart using plot() method and previous variable. Use parameters to add percentage.
vc.plot(kind='pie',autopct='%.1f')

#Do the same without using variable.
df.gender.value_counts().plot(kind='pie',autopct='%.1f')

# %% [markdown]
# ### Favorite color
#
# Next, we'll display people's favorites colors
# 1. Show people's favorites colors in a barchart
# 2. Change the bar's default color
#
# #### Do it yourself

# %%
# Count color's values and use plot() methode to display a green bar graph
df.color.value_counts().plot(kind='bar', color='green')

# %% [markdown]
# ### Height
#
# Then, we'll display people's height
# 1. Display minimum, maximum, quartiles and median of the height
#
# #### Do it yourself

# %%
# Use plot method to display a boxplot of height
df.height.plot(kind='box')

# %% [markdown]
# ###	Correlation with feeling and sleep (difficult)
# Let's do a correlation between feeling and sleep. Like that we could know if the sleep affect the feelings.
#
# You can do this in multiple way :
# - with multiple boxplots
# - multiple histograms
# - one graph with multiple histograms inside
#
# Tips :
# - You can do this <pre>df[['thing', 'else']]</pre>
# - Check the [documentation](https://pandas.pydata.org/pandas-docs/stable/visualization.html#histograms)

# %%
#Use multiple key for viz
#multiple boxplots
df[['feeling', 'sleep']].groupby('feeling').boxplot(subplots=False)
#multiple hist
df[['feeling', 'sleep']].hist(by='feeling')

#one graph multiple hist
fig, ax = plt.subplots()
for label in df.feeling.unique():
    s = df[df['feeling'] == label].sleep
    s.plot(kind='hist', ax=ax, label=label)
plt.legend()
